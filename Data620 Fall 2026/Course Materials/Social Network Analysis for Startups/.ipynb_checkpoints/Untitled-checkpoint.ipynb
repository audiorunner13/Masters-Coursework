# %% [markdown]
# ACME Org Chart - Chapter 1

# %%
import networkx as net
import matplotlib.pyplot as plot

# %%
orgchart=net.read_pajek("/Users/Audiorunner13/CUNY MSDS Course Work/Data620 Spring 2024/Week 1/ACME_orgchart.net")
net.draw(orgchart, with_labels=True)

# %%
orgchart_result = net.read_pajek("/Users/Audiorunner13/CUNY MSDS Course Work/Data620 Spring 2024/Week 1/ACME_advice.net")
net.draw(orgchart_result, with_labels=True)
