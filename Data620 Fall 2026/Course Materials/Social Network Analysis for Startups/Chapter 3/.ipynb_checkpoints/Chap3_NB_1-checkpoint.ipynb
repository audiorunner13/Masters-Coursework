# %% [markdown]
# Chapter 3. Centrality, Power, and Bottlenecks

# %%
import networkx as net
import urllib

# %%
# create a blank graphj
g=net.Graph()

# insert an edger into the graph; nodes will be inserted automatically.
g.add_edge('a','b')  
g.add_edge('b','c')
g.add_edge('c','a')

# draw the graph

net.draw(g,with_labels=True)

# %%
#list the nodes
list(g.nodes())
# Out:
# ['a', 'b', 'c']

# %%
#list the edges
list(g.edges())
# Out:
# [('a', 'b'), ('a', 'c'), ('b', 'c')]

# %%
g.nodes['a']
# Out:
# {}

# %%
g.nodes['a']['size']=1

# %%
g.nodes['a']
# Out:
# {'size': 1}

# %%
g['a']
# Out:
# AtlasView({'b': {}, 'c': {}})

# %%
g['a']['b']
# Out:
# {}

# %%
g['a']['b']['weight']=1

# %%
g['a']['b']
# Out:
# {'weight': 1}
