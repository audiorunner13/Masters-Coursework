# %% [markdown]
# Hello, graph world - Krackhardt Kite

# %%
import matplotlib.pyplot as plt

# %%
import networkx as nx

# %%
# Create the nodes (individuals) and their edges (neighbors)

neighbors={'Andre':['Fernando', 'Beverly', 'Diane','Carol'], 'Beverly':['Andre','Diane','Garth','Ed'],
           'Diane':['Fernando', 'Beverly', 'Andre', 'Garth','Ed','Carol'],'Carol':['Andre','Diane','Fernando'], 
           'Fernando':['Carol','Andre','Diane', 'Garth', 'Heather'], 'Ed':['Beverly', 'Diane', 'Garth'], 
           'Garth':['Ed','Beverly','Diane','Fernando','Heather'], 'Heather':['Garth','Fernando','Ike'], 
           'Ike':['Heather', 'Jane'], 'Jane':['Ike']}

# %%
print(neighbors)
# Out:
# {'Andre': ['Fernando', 'Beverly', 'Diane', 'Carol'], 'Beverly': ['Andre', 'Diane', 'Garth', 'Ed'], 'Diane': ['Fernando', 'Beverly', 'Andre', 'Garth', 'Ed', 'Carol'], 'Carol': ['Andre', 'Diane', 'Fernando'], 'Fernando': ['Carol', 'Andre', 'Diane', 'Garth', 'Heather'], 'Ed': ['Beverly', 'Diane', 'Garth'], 'Garth': ['Ed', 'Beverly', 'Diane', 'Fernando', 'Heather'], 'Heather': ['Garth', 'Fernando', 'Ike'], 'Ike': ['Heather', 'Jane'], 'Jane': ['Ike']}

# %%
G = nx.Graph()

# %%
for neighbor in neighbors:
    G.add_node(neighbor)
    for n in neighbors[neighbor]:
        G.add_edge(neighbor, n)
        
print(G.nodes)
# Out:
# ['Andre', 'Fernando', 'Beverly', 'Diane', 'Carol', 'Garth', 'Ed', 'Heather', 'Ike', 'Jane']

# %%
print(G.edges)
# Out:
# [('Andre', 'Fernando'), ('Andre', 'Beverly'), ('Andre', 'Diane'), ('Andre', 'Carol'), ('Fernando', 'Diane'), ('Fernando', 'Carol'), ('Fernando', 'Garth'), ('Fernando', 'Heather'), ('Beverly', 'Diane'), ('Beverly', 'Garth'), ('Beverly', 'Ed'), ('Diane', 'Garth'), ('Diane', 'Ed'), ('Diane', 'Carol'), ('Garth', 'Ed'), ('Garth', 'Heather'), ('Heather', 'Ike'), ('Ike', 'Jane')]

# %%
nx.draw_networkx(G, node_color = 'r', edge_color = 'b', with_labels=True)
